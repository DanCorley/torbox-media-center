# %%
import niquests

# %%
TORBOX_API_URL = "https://api.torbox.app/v1/api"
TORBOX_SEARCH_API_URL = "https://search-api.torbox.app"
TORBOX_API_KEY="3d9a0625-a8f9-4615-9c9e-687f9678d977"

# %%
r = niquests.get(
  TORBOX_API_URL + "/torrents/mylist",
  headers={"Authorization": f"Bearer {TORBOX_API_KEY}"},
  params={"limit": 1000, "offset": 0, "bypass_cache": True}
)

{
  movie['name']: movie['tags'] for movie in r.json()['data']
  if 'How.To.Make' in movie['name']
    or movie['tags'] != []
}
# Out:
# {'How.To.Make.a.Killing.2026.HDR.2160p.WEB.h265-ETHEL': ['folder=none'],
#  'Louis.Theroux.Plongee.dans.la.manosphere.2026.DOC.MULTi.VFF.1080p.WEB.EAC3.5.1.x264-FW': ['folder=adult']}

# %%
[
  movie for movie in r.json()['data']
  if 'Loki' in movie['name']
    # or movie['tags'] != []
]
# Out:
# [{'id': 16835606,
#   'auth_id': 'd002d211-e364-4e4e-9e82-7b6875b28973',
#   'server': 0,
#   'hash': 'f0b6840964dbc1fd63b2444f7fcb43453965bc90',
#   'name': 'Loki - Season 02 [2023] 2160p UHD BDRip DV HDR10 x265 TrueHD Atmos 7.1 Kira [SEV]',
#   'magnet': None,
#   'size': 67384888890,
#   'active': False,
#   'created_at': '2026-03-11T19:32:56Z',
#   'updated_at': '2026-03-11T19:32:56Z',
#   'download_state': 'cached',
#   'seeds': 0,
#   'peers': 0,
#   'ratio': 0,
#   'progress': 1,
#   'download_speed': 0,
#   'upload_speed': 0,
#   'eta': 0,
#   'torrent_file': False,
#   'expires_at': None,
#   'download_present': True,
#   'files': [{'id': 5,
#     'md5': None,
#     'hash': 'f0b6840964dbc1fd63b2444f7fcb43453965bc90',
#     'name': 'Loki - Season 02 [2023] 2160p UHD BDRip DV HDR10 x265 TrueHD Atmos 7.1 Kira [SEV]/Loki - S02.E01 - Ouroboros 2160p UHD BDRip DV HDR10 x265 TrueHD Atmos 7.1 Kira [SEV].mkv',
#     'size': 10364691133,
#     'zipped': False,
# ...

# %%
# * dan-test-branch
#   file-by-create-date
#   list
#   ls
#   main
#   skip-sample-files
